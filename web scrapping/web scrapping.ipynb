# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from bs4 import BeautifulSoup
import requests as r

data = r.get('https://learn-tagalog.com/tagalog-translations-1/',headers={"User-Agent": "XY"}).text
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="en-US">\n<head itemscope itemtype="http://schema.org/WebSite">\n\t<meta charset="UTF-8">\n\t<!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame -->\n\t<!--[if IE ]>\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t<![endif]-->\n\t<link rel="profile" href="https://gmpg.org/xfn/11" />\n\t\n\t\t\n\t\t\n\t\t\n\t\t\t\t\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t\t\t<meta name="apple-mobile-web-app-capable" content="yes">\n\t\t\t<meta name="apple-mobile-web-app-status-bar-style" content="black">\n\t\t\n\t\t\n\t\t<meta itemprop="name" content="Learn Tagalog" />\n\t\t<meta itemprop="url" content="https://learn-tagalog.com" />\n\n\t\t\t\t\t\t\t\t\t\t\t\t<meta itemprop="creator accountablePerson" content="Admin Guy" />\n\t\t\t\t\t\t<link rel="pingback" href="https://learn-tagalog.com/xmlrpc.php" />\n\t<script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygo
# ...

# %%
soup = BeautifulSoup(data)

# %%
<tr class="rowcolor1">
<td width="50"><div class="sc_player_container1"><input type="button" id="btnplay_5e23328e747006.12601019" class="myButton_play" onclick="play_mp3('play','5e23328e747006.12601019','https://learn-tagalog.com/audio/01.mp3','80','false');show_hide('play','5e23328e747006.12601019');" style="display: inline;"><input type="button" id="btnstop_5e23328e747006.12601019" style="display: none;" class="myButton_stop" onclick="play_mp3('stop','5e23328e747006.12601019','','80','false');show_hide('stop','5e23328e747006.12601019');"><div id="sm2-container"><!-- flash movie ends up here --></div></div></td>
<td>Aabot sa apatlumpung kilo ang timbang mo.</td>
<td>You weigh at least forty kilos.</td>
</tr>

# %%
phrases = soup.find_all('tr', class_=lambda s:s.startswith('rowcolor'))

# %%
 file_name = phrases[0].find_all('td')[1].text.replace(' ',"") + 'mp3'

# %%
import string

# %%
''.join(ch for ch in file_name if ch.isalnum())
# Out:
# 'Aabotsaapatlumpungkiloangtimbangmomp3'

# %%
import re

# %%
url_tag = phrases[0].find('input',class_="myButton_play").get('onclick')

# %%
url = re.search('(https.*mp3)',url_tag).group(1)

# %%
import os

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/taglog'

# %%
cd ..
# Out:
# /content/drive/My Drive

# %%
os.mkdir('tagalog')

# %%
cd 'tagalog'
# Out:
# /content/drive/My Drive/tagalog

# %%
import time

# %%
for  n in range(len(phrases)):
  try:
    file_name =  phrases[n].find_all('td')[1].text.replace(' ',"")
    file_name =''.join(ch for ch in file_name if ch.isalnum())+ '.mp3'
    url_tag = phrases[n].find('input',class_="myButton_play").get('onclick')
    url = re.search('(https.*mp3)',url_tag).group(1)
    open(file_name , 'wb').write (r.get(url,headers={"User-Agent": "XY"}).content)
    print(file_name)
    time.sleep(2)
  except:
    pass
    print(file_name + 'passed')
# Out:
# Aabotsaapatlumpungkiloangtimbangmo.mp3
# Aabotsalimangmetroanglapadnito.mp3
# Aahonsatubigangbabae.mp3
# Aahonsatubigangbatanglalaki.mp3
# Aakyatnghagdanangmgatao.mp3
# AakyatnghagdansiMaria.mp3
# Aakyatngpaderanglalakingnakaputingkamiseta.mp3
# Aalagaankita.mp3
# Aalisakobukas.mp3
# Aalisako.mp3
# Aalisakongmagisa.mp3
# Aalisakongmagisangbukas.mp3
# Aalisakongmagisangngayongaraw.mp3
# Aalisangbusngalasdiyeskinse.mp3
# Aalisangbusngalasdiyesymedyanggabi.mp3
# Aalisangbusngalassaisymedyanggabi.mp3
# Aalisangbusngalassietengumaga.mp3
# Aalisangbusngalaunaymedya.mp3
# Aalisangbussaalassingkokinse.mp3
# Aalisangbussaalassingkoykuwarto.mp3
# Aalisangeroplanongalaskuwatronghapon.mp3
# AalisangflightkosaMiyerkulesmulasaBaguio.mp3
# Aalisangflightngalasdoskinsenghapon.mp3
# Aalisangflightngalasotsobeintesingkongumaga.mp3
# Aalisangflightsaloobngtatlumpungminuto.mp3
# Aalisbaangflightngalassinkosingkuwentaysingkongumaga.mp3
# Aalisnaako.mp3
# Aalisnaakobukas.mp3
# Aalisnaakomagisa.mp3
# ...

# %%
len(phrases)
# Out:
# 99
